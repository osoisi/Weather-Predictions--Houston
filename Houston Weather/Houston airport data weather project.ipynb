# %% [markdown]
# # Weather Predictions
# ## Houston Airport Data Weather Project
# This project aims to provide accurate weather predictions for the city of Houston, Texas.
#
# ## Project Overview
# The project uses a Python notebook to read csv data downloaded from the NCDC weather website, preprocess it, and visualize it using Matplotlib and Seaborn. The data is then used to train a machine learning model to predict the weather in Houston. The model is then evaluated using the test data and the results are visualized using Matplotlib and Seaborn.
#
# ### Data Source
# The data used in this project is sourced from Houston's airport, specifically focusing on key weather variables such as wind speed, pressure, temperature, humidity, and wind direction. This data is crucial for understanding the local weather patterns and making accurate predictions.
# Find the data [here](https://www.ncdc.noaa.gov/cdo-web/search)
#
# ## Features
# * Precipitation - The amount of rain that falls in a day.
# * Maximum temperature - The highest temperature recorded in a day.
# * Mininmum temperature - The lowest temperature recorded in a day.

# %%
import pandas as pd

# %%
weather = pd.read_csv('Houston airport data - 3722516.csv', index_col='DATE')

# %%
weather.head()
# Out:
#                 STATION                                     NAME   ACMH  \
# DATE
# 1969-06-01  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US   50.0
# 1969-06-02  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US   70.0
# 1969-06-03  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US  100.0
# 1969-06-04  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US   90.0
# 1969-06-05  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US   50.0
#
#              ACSH  AWND  FMTM    PGTM  PRCP  PSUN  SNOW  ...  WT10  WT11  \
# DATE                                                     ...
# 1969-06-01   50.0   NaN   NaN     NaN  0.00  67.0   0.0  ...   NaN   NaN
# 1969-06-02   60.0   NaN   NaN     NaN  0.18  57.0   0.0  ...   NaN   NaN
# 1969-06-03  100.0   NaN   NaN  1100.0  0.06  10.0   0.0  ...   NaN   NaN
# 1969-06-04  100.0   NaN   NaN   906.0  1.27   0.0   0.0  ...   NaN   NaN
# 1969-06-05   80.0   NaN   NaN  1048.0  0.00  24.0   0.0  ...   NaN   NaN
#
# ...

# %%
weather.loc["1972-01-01":]
# Out:
#                 STATION                                     NAME   ACMH  \
# DATE
# 1972-01-01  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US  100.0
# 1972-01-02  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US   40.0
# 1972-01-03  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US   90.0
# 1972-01-04  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US  100.0
# 1972-01-05  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US   40.0
# ...                 ...                                      ...    ...
# 2024-06-14  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US    NaN
# 2024-06-15  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US    NaN
# 2024-06-16  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US    NaN
# 2024-06-17  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US    NaN
# 2024-06-18  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US    NaN
#
#              ACSH   AWND  FMTM    PGTM  PRCP  PSUN  SNOW  ...  WT10  WT11  \
# ...

# %%
weather
# Out:
#                 STATION                                     NAME   ACMH  \
# DATE
# 1969-06-01  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US   50.0
# 1969-06-02  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US   70.0
# 1969-06-03  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US  100.0
# 1969-06-04  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US   90.0
# 1969-06-05  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US   50.0
# ...                 ...                                      ...    ...
# 2024-06-14  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US    NaN
# 2024-06-15  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US    NaN
# 2024-06-16  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US    NaN
# 2024-06-17  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US    NaN
# 2024-06-18  USW00012960  HOUSTON INTERCONTINENTAL AIRPORT, TX US    NaN
#
#              ACSH   AWND  FMTM    PGTM  PRCP  PSUN  SNOW  ...  WT10  WT11  \
# ...

# %%
weather.shape
# Out:
# (20107, 43)

# %%
weather.isnull().sum()/weather.shape[0]*100
# Out:
# STATION     0.000000
# NAME        0.000000
# ACMH       50.952405
# ACSH       50.952405
# AWND       26.528075
# FMTM       49.336052
# PGTM       27.383498
# PRCP        0.004973
# PSUN       73.506739
# SNOW        0.009947
# SNWD        0.024867
# TAVG       66.315214
# TMAX        0.004973
# TMIN        0.004973
# TSUN       43.621624
# WDF1       50.957378
# WDF2       49.062516
# WDF5       49.296265
# WDFG       51.290595
# WESD       70.935495
# WSF1       50.957378
# WSF2       49.062516
# WSF5       49.286318
# WSFG       51.275675
# WT01       51.957030
# WT02       93.380415
# WT03       82.682648
# WT04       99.791118
# WT05       98.463222
# WT06       99.736410
# WT07       99.651863
# WT08       77.082608
# WT09       99.870692
# WT10       99.995027
# WT11       99.900532
# WT13       87.099020
# WT14       97.125379
# WT15       99.920426
# WT16       67.966380
# WT17       99.910479
# WT18       99.840851
# WT21       99.099816
# WV03       99.970160
# ...

# %%
weather.columns
# Out:
# Index(['STATION', 'NAME', 'ACMH', 'ACSH', 'AWND', 'FMTM', 'PGTM', 'PRCP',
#        'PSUN', 'SNOW', 'SNWD', 'TAVG', 'TMAX', 'TMIN', 'TSUN', 'WDF1', 'WDF2',
#        'WDF5', 'WDFG', 'WESD', 'WSF1', 'WSF2', 'WSF5', 'WSFG', 'WT01', 'WT02',
#        'WT03', 'WT04', 'WT05', 'WT06', 'WT07', 'WT08', 'WT09', 'WT10', 'WT11',
#        'WT13', 'WT14', 'WT15', 'WT16', 'WT17', 'WT18', 'WT21', 'WV03'],
#       dtype='object')

# %%
core_weather = weather[['PRCP', 'SNOW', 'SNWD', 'TMAX', 'TMIN']].copy()

# %%
core_weather.head(5)
# Out:
#             PRCP  SNOW  SNWD  TMAX  TMIN
# DATE
# 1969-06-01  0.00   0.0   0.0  90.0  72.0
# 1969-06-02  0.18   0.0   0.0  85.0  62.0
# 1969-06-03  0.06   0.0   0.0  80.0  60.0
# 1969-06-04  1.27   0.0   0.0  66.0  60.0
# 1969-06-05  0.00   0.0   0.0  78.0  56.0

# %%
core_weather.columns = ['Precip','Snow','Snow_depth', 'Max_temp','Min_temp']

# %%
core_weather=core_weather.drop(columns=['Snow','Snow_depth'])

# %%
core_weather.head()
# Out:
#             Precip  Max_temp  Min_temp
# DATE
# 1969-06-01    0.00      90.0      72.0
# 1969-06-02    0.18      85.0      62.0
# 1969-06-03    0.06      80.0      60.0
# 1969-06-04    1.27      66.0      60.0
# 1969-06-05    0.00      78.0      56.0

# %%
core_weather.describe()
# Out:
#              Precip      Max_temp      Min_temp
# count  20106.000000  20106.000000  20106.000000
# mean       0.136156     79.833880     59.307719
# std        0.485107     13.544924     14.301519
# min        0.000000     25.000000      7.000000
# 25%        0.000000     72.000000     48.000000
# 50%        0.000000     82.000000     62.000000
# 75%        0.020000     91.000000     72.000000
# max       16.070000    109.000000     84.000000

# %%
core_weather.isnull().sum()
# Out:
# Precip      1
# Max_temp    1
# Min_temp    1
# dtype: int64

# %%
core_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20107 entries, 1969-06-01 to 2024-06-18
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Precip    20106 non-null  float64
#  1   Max_temp  20106 non-null  float64
#  2   Min_temp  20106 non-null  float64
# dtypes: float64(3)
# memory usage: 1.1+ MB

# %%
#core_weather['Snow'].value_counts()

# %%
core_weather[pd.isnull(core_weather['Precip'])]
# Out:
#             Precip  Max_temp  Min_temp
# DATE
# 2024-06-18     NaN       NaN       NaN

# %%
core_weather[pd.isnull(core_weather['Max_temp'])]
# Out:
#             Precip  Max_temp  Min_temp
# DATE
# 2024-06-18     NaN       NaN       NaN

# %%
core_weather[pd.isnull(core_weather['Min_temp'])]
# Out:
#             Precip  Max_temp  Min_temp
# DATE
# 2024-06-18     NaN       NaN       NaN

# %%
core_weather.loc['2024-06-1':'2024-06-30']
# Out:
#             Precip  Max_temp  Min_temp
# DATE
# 2024-06-10    2.60      93.0      73.0
# 2024-06-11    2.97      93.0      73.0
# 2024-06-12    0.00      92.0      74.0
# 2024-06-13    0.00      94.0      76.0
# 2024-06-14    0.00      95.0      76.0
# 2024-06-15    0.00      93.0      75.0
# 2024-06-16    0.00      94.0      75.0
# 2024-06-17    0.00      92.0      77.0
# 2024-06-18     NaN       NaN       NaN

# %%
core_weather['Precip']=core_weather['Precip'].fillna(0)

# %%
core_weather[(pd.isnull(core_weather['Min_temp']))|(pd.isnull(core_weather['Max_temp']))]
# Out:
#             Precip  Max_temp  Min_temp
# DATE
# 2024-06-18     0.0       NaN       NaN

# %%
core_weather.isnull().sum()
# Out:
# Precip      0
# Max_temp    1
# Min_temp    1
# dtype: int64

# %%
core_weather=core_weather.ffill()

# %%
core_weather.isnull().sum()
# Out:
# Precip      0
# Max_temp    0
# Min_temp    0
# dtype: int64

# %%
core_weather.dtypes
# Out:
# Precip      float64
# Max_temp    float64
# Min_temp    float64
# dtype: object

# %%
core_weather.index
# Out:
# Index(['1969-06-01', '1969-06-02', '1969-06-03', '1969-06-04', '1969-06-05',
#        '1969-06-06', '1969-06-07', '1969-06-08', '1969-06-09', '1969-06-10',
#        ...
#        '2024-06-09', '2024-06-10', '2024-06-11', '2024-06-12', '2024-06-13',
#        '2024-06-14', '2024-06-15', '2024-06-16', '2024-06-17', '2024-06-18'],
#       dtype='object', name='DATE', length=20107)

# %%
core_weather.index=pd.to_datetime(core_weather.index)

# %%
core_weather.index
# Out:
# DatetimeIndex(['1969-06-01', '1969-06-02', '1969-06-03', '1969-06-04',
#                '1969-06-05', '1969-06-06', '1969-06-07', '1969-06-08',
#                '1969-06-09', '1969-06-10',
#                ...
#                '2024-06-09', '2024-06-10', '2024-06-11', '2024-06-12',
#                '2024-06-13', '2024-06-14', '2024-06-15', '2024-06-16',
#                '2024-06-17', '2024-06-18'],
#               dtype='datetime64[ns]', name='DATE', length=20107, freq=None)

# %%
core_weather.index.year
# Out:
# Index([1969, 1969, 1969, 1969, 1969, 1969, 1969, 1969, 1969, 1969,
#        ...
#        2024, 2024, 2024, 2024, 2024, 2024, 2024, 2024, 2024, 2024],
#       dtype='int32', name='DATE', length=20107)

# %%
core_weather.apply(lambda x: (x==9999).sum())
# Out:
# Precip      0
# Max_temp    0
# Min_temp    0
# dtype: int64

# %%
core_weather[['Max_temp', 'Min_temp']].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
cw_year = core_weather.index.year
cw_precip = core_weather['Precip']

# %%
#df_yearly_precip=pd.DataFrame({'Year': cw_year, 'Precip':cw_precip}).reset_index()
df_yearly_precip=pd.DataFrame({'Year': cw_year, 'Precip':cw_precip})

# %%
df_yearly_precip.head(5)
# Out:
#             Year  Precip
# DATE
# 1969-06-01  1969    0.00
# 1969-06-02  1969    0.18
# 1969-06-03  1969    0.06
# 1969-06-04  1969    1.27
# 1969-06-05  1969    0.00

# %%
df_yearly_precip['Precip'].plot(figsize=(10,10))
# Out:
# <Axes: xlabel='DATE'>

# %%
df_yearly_precip.plot(kind='scatter', x='Year', y='Precip', figsize=(10,10))
# Out:
# <Axes: xlabel='Year', ylabel='Precip'>

# %%
core_weather.apply(lambda x: (x>110)).sum()
# Out:
# Precip      0
# Max_temp    0
# Min_temp    0
# dtype: int64

# %%
core_weather[core_weather['Min_temp']<15].sort_values(by='Min_temp')
# Out:
#             Precip  Max_temp  Min_temp
# DATE
# 1989-12-23    0.00      28.0       7.0
# 1983-12-25    0.00      28.0      11.0
# 1989-12-24    0.00      43.0      11.0
# 1982-01-11    0.00      34.0      12.0
# 1989-12-22    0.14      34.0      13.0
# 2021-02-16    0.00      35.0      13.0
# 1983-12-24    0.00      27.0      14.0

# %%
core_weather.loc['1989-12-20':]
# Out:
#             Precip  Max_temp  Min_temp
# DATE
# 1989-12-20    0.00      46.0      33.0
# 1989-12-21    0.00      46.0      30.0
# 1989-12-22    0.14      34.0      13.0
# 1989-12-23    0.00      28.0       7.0
# 1989-12-24    0.00      43.0      11.0
# ...            ...       ...       ...
# 2024-06-14    0.00      95.0      76.0
# 2024-06-15    0.00      93.0      75.0
# 2024-06-16    0.00      94.0      75.0
# 2024-06-17    0.00      92.0      77.0
# 2024-06-18    0.00      92.0      77.0
#
# [12600 rows x 3 columns]

# %%
df_weather_yearly=core_weather.index.year.value_counts()

# %%
df_weather_yearly.head(5)
# Out:
# DATE
# 1996    366
# 2016    366
# 2004    366
# 1992    366
# 2008    366
# Name: count, dtype: int64

# %%
dfw_columns = ['Year','Count']

# %%
df_weather_yearly.columns = dfw_columns

# %%
df_weather_yearly.plot(kind='bar',x='Year', y='Count', figsize=(10,10))
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather.columns
# Out:
# Index(['Precip', 'Max_temp', 'Min_temp'], dtype='object')

# %%
df_yearly_weather_mean=core_weather.groupby(core_weather.index.year).mean()

# %%
#weather_data_ready=pd.DataFrame(core_weather[~((core_weather.index.year ==1969)|(core_weather.index.year ==2024))]).reset_index()
weather_data_ready=pd.DataFrame(core_weather[~((core_weather.index.year ==1969)|(core_weather.index.year ==2024))])

# %%
weather_data_ready.head(5)
# Out:
#             Precip  Max_temp  Min_temp
# DATE
# 1970-01-01    0.00      56.0      25.0
# 1970-01-02    0.19      45.0      32.0
# 1970-01-03    0.00      51.0      29.0
# 1970-01-04    0.07      53.0      26.0
# 1970-01-05    0.78      50.0      40.0

# %%
weather_data_ready['Target_max'] = weather_data_ready.shift(-1)['Max_temp']

# %%
weather_data_ready
# Out:
#             Precip  Max_temp  Min_temp  Target_max
# DATE
# 1970-01-01    0.00      56.0      25.0        45.0
# 1970-01-02    0.19      45.0      32.0        51.0
# 1970-01-03    0.00      51.0      29.0        53.0
# 1970-01-04    0.07      53.0      26.0        50.0
# 1970-01-05    0.78      50.0      40.0        40.0
# ...            ...       ...       ...         ...
# 2023-12-27    0.00      66.0      43.0        58.0
# 2023-12-28    0.00      58.0      39.0        56.0
# 2023-12-29    0.00      56.0      37.0        66.0
# 2023-12-30    0.00      66.0      35.0        73.0
# 2023-12-31    0.00      73.0      38.0         NaN
#
# [19723 rows x 4 columns]

# %%
weather_data_ready.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 19723 entries, 1970-01-01 to 2023-12-31
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Precip      19723 non-null  float64
#  1   Max_temp    19723 non-null  float64
#  2   Min_temp    19723 non-null  float64
#  3   Target_max  19722 non-null  float64
# dtypes: float64(4)
# memory usage: 770.4 KB

# %%
weather_data_ready = weather_data_ready.dropna()

# %%
weather_data_ready.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 19722 entries, 1970-01-01 to 2023-12-30
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Precip      19722 non-null  float64
#  1   Max_temp    19722 non-null  float64
#  2   Min_temp    19722 non-null  float64
#  3   Target_max  19722 non-null  float64
# dtypes: float64(4)
# memory usage: 770.4 KB

# %%
from sklearn.linear_model import Ridge
reg = Ridge(alpha=.1)

# %%
predictors = ['Precip',	'Max_temp',	'Min_temp']

# %%
weather_data_ready[weather_data_ready.index <'2020-01-01']
# Out:
#             Precip  Max_temp  Min_temp  Target_max
# DATE
# 1970-01-01    0.00      56.0      25.0        45.0
# 1970-01-02    0.19      45.0      32.0        51.0
# 1970-01-03    0.00      51.0      29.0        53.0
# 1970-01-04    0.07      53.0      26.0        50.0
# 1970-01-05    0.78      50.0      40.0        40.0
# ...            ...       ...       ...         ...
# 2019-12-27    0.00      69.0      54.0        78.0
# 2019-12-28    0.10      78.0      63.0        70.0
# 2019-12-29    0.73      70.0      49.0        62.0
# 2019-12-30    0.00      62.0      39.0        62.0
# 2019-12-31    0.00      62.0      36.0        60.0
#
# [18262 rows x 4 columns]

# %% [markdown]
# ## Train with old data and predict with new data.

# %%
train = weather_data_ready.loc[:'2022-12-31']
test = weather_data_ready.loc['2023-01-01':]

# %%
#midpoint = len(weather_data_ready) // 2
#weather_data_ready.iloc[:midpoint]

# %%
reg.fit(train[predictors], train['Target_max'])
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])

# %%
from sklearn.metrics import mean_absolute_error

# %%
error = mean_absolute_error(test['Target_max'], predictions)

# %%
error
# Out:
# 4.50851049172329

# %% [markdown]
# it means I am about 4.467% different from the target.
# Model needs improvement

# %%
combined = pd.concat([test['Target_max'], pd.Series(predictions, index=test.index)], axis=1)

# %%
combined.columns = ['actual', 'predictions']

# %%
combined
# Out:
#             actual  predictions
# DATE
# 2023-01-01    76.0    79.306293
# 2023-01-02    78.0    78.775532
# 2023-01-03    72.0    78.280054
# 2023-01-04    72.0    72.420536
# 2023-01-05    79.0    71.654352
# ...            ...          ...
# 2023-12-26    66.0    60.641102
# 2023-12-27    58.0    67.197080
# 2023-12-28    56.0    60.641102
# 2023-12-29    66.0    58.848871
# 2023-12-30    73.0    65.971185
#
# [364 rows x 2 columns]

# %%
combined.plot(figsize=(10,10))
# Out:
# <Axes: xlabel='DATE'>

# %%
reg.coef_
# Out:
# array([-1.08435768,  0.74287874,  0.15323684])

# %% [markdown]
# Precipitation (-1.23369659) is negatively related to the target.
# Temerature Max (0.74223256) is positively related to the target. It has the most impact on the target.
# Temperature Min (0.1512336) is positively related to the target but only marginally.

# %%
def create_predications(predicators, weather_data_ready, reg):
    train = weather_data_ready.loc[:'1999-12-31']
    test = weather_data_ready.loc['2020-01-01':]
    reg.fit(train[predictors], train['Target_max'])
    predictions = reg.predict(test[predictors])
    mean_absolute_error(test['Target_max'], predictions)
    combined = pd.concat([test['Target_max'], pd.Series(predictions, index=test.index)], axis=1)
    combined.columns = ['actual', 'predictions']
    return error, combined

# %%
#weather_data_ready['month_max'] = weather_data_ready['Max_temp'].rolling(30).mean()
weather_data_ready.loc[:, 'month_max'] = weather_data_ready['Max_temp'].rolling(30).mean()
# Out:
# C:\Users\aa1\AppData\Local\Temp\ipykernel_45232\1042744306.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weather_data_ready.loc[:, 'month_max'] = weather_data_ready['Max_temp'].rolling(30).mean()

# %% [markdown]
# This code uses .loc to specify that you want to add or modify the 'month_max' column in the weather_data_ready DataFrame. The : indicates that you want to apply this operation to all rows, and 'month_max' specifies the column you're assigning the rolling mean to. This approach makes your intention clear to pandas, helping avoid the SettingWithCopyWarning.

# %%
weather_data_ready
# Out:
#             Precip  Max_temp  Min_temp  Target_max  month_max
# DATE
# 1970-01-01    0.00      56.0      25.0        45.0        NaN
# 1970-01-02    0.19      45.0      32.0        51.0        NaN
# 1970-01-03    0.00      51.0      29.0        53.0        NaN
# 1970-01-04    0.07      53.0      26.0        50.0        NaN
# 1970-01-05    0.78      50.0      40.0        40.0        NaN
# ...            ...       ...       ...         ...        ...
# 2023-12-26    0.00      58.0      39.0        66.0  67.966667
# 2023-12-27    0.00      66.0      43.0        58.0  68.166667
# 2023-12-28    0.00      58.0      39.0        56.0  68.000000
# 2023-12-29    0.00      56.0      37.0        66.0  67.633333
# 2023-12-30    0.00      66.0      35.0        73.0  67.500000
#
# [19722 rows x 5 columns]

# %%
weather_data_ready.loc[:,'month_day_max'] = weather_data_ready['month_max']/weather_data_ready['Max_temp']
# Out:
# C:\Users\aa1\AppData\Local\Temp\ipykernel_45232\3995088799.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weather_data_ready.loc[:,'month_day_max'] = weather_data_ready['month_max']/weather_data_ready['Max_temp']

# %%
weather_data_ready.loc[:,'max_min'] = weather_data_ready['Max_temp'] / weather_data_ready['Min_temp']
# Out:
# C:\Users\aa1\AppData\Local\Temp\ipykernel_45232\1162033544.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weather_data_ready.loc[:,'max_min'] = weather_data_ready['Max_temp'] / weather_data_ready['Min_temp']

# %%
weather_data_ready
# Out:
#             Precip  Max_temp  Min_temp  Target_max  month_max  month_day_max  \
# DATE
# 1970-01-01    0.00      56.0      25.0        45.0        NaN            NaN
# 1970-01-02    0.19      45.0      32.0        51.0        NaN            NaN
# 1970-01-03    0.00      51.0      29.0        53.0        NaN            NaN
# 1970-01-04    0.07      53.0      26.0        50.0        NaN            NaN
# 1970-01-05    0.78      50.0      40.0        40.0        NaN            NaN
# ...            ...       ...       ...         ...        ...            ...
# 2023-12-26    0.00      58.0      39.0        66.0  67.966667       1.171839
# 2023-12-27    0.00      66.0      43.0        58.0  68.166667       1.032828
# 2023-12-28    0.00      58.0      39.0        56.0  68.000000       1.172414
# 2023-12-29    0.00      56.0      37.0        66.0  67.633333       1.207738
# 2023-12-30    0.00      66.0      35.0        73.0  67.500000       1.022727
#
#              max_min
# DATE
# ...

# %%
weather_data_ready=weather_data_ready.dropna()

# %%
predictors = ['Precip', 'Max_temp', 'Min_temp', 'month_max', 'month_day_max', 'max_min']

# %%
error, combined = create_predications(predictors, weather_data_ready, reg)

# %%
error
# Out:
# 4.50851049172329

# %% [markdown]
# Error was 4.348389105418288 and now 4.348389105418288

# %%
weather_data_ready.loc[:,'monthly_avg']=weather_data_ready['Max_temp'].groupby(weather_data_ready.index.month).transform(lambda a: a.expanding(1).mean())

# %%
weather_data_ready
# Out:
#             Precip  Max_temp  Min_temp  Target_max  month_max  month_day_max  \
# DATE
# 1970-01-30    0.00      58.0      32.0        54.0  55.800000       0.962069
# 1970-01-31    0.05      54.0      31.0        64.0  55.733333       1.032099
# 1970-02-01    1.08      64.0      50.0        56.0  56.366667       0.880729
# 1970-02-02    0.00      56.0      34.0        50.0  56.533333       1.009524
# 1970-02-03    0.00      50.0      27.0        64.0  56.433333       1.128667
# ...            ...       ...       ...         ...        ...            ...
# 2023-12-26    0.00      58.0      39.0        66.0  67.966667       1.171839
# 2023-12-27    0.00      66.0      43.0        58.0  68.166667       1.032828
# 2023-12-28    0.00      58.0      39.0        56.0  68.000000       1.172414
# 2023-12-29    0.00      56.0      37.0        66.0  67.633333       1.207738
# 2023-12-30    0.00      66.0      35.0        73.0  67.500000       1.022727
#
#              max_min  monthly_avg
# ...
